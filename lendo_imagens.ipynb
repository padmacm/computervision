# %%
pip install opencv-contrib-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2

#Função Imread - é a função de leitura de imagem

img = cv2.imread('assets/fotos/cat.jpg')
cv2.imshow('Janela do Gato', img) #imshow determina a exibição da imagem
cv2.waitKey(0) #waitkey determina o tempo de exibição da tela
