# %%
pip install opencv-contrib-python
# Out:
# ...
#    ---------------------------------------- 0.0/46.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/46.5 MB 640.0 kB/s eta 0:01:13
#    ---------------------------------------- 0.2/46.5 MB 2.9 MB/s eta 0:00:17
#     --------------------------------------- 0.7/46.5 MB 5.7 MB/s eta 0:00:08
#    - -------------------------------------- 2.2/46.5 MB 13.9 MB/s eta 0:00:04
#    --- ------------------------------------ 3.6/46.5 MB 16.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 5.2/46.5 MB 20.9 MB/s eta 0:00:02
#    ------ --------------------------------- 7.4/46.5 MB 24.7 MB/s eta 0:00:02
#    ------- -------------------------------- 9.2/46.5 MB 28.2 MB/s eta 0:00:02
#    --------- ------------------------------ 11.2/46.5 MB 40.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 13.0/46.5 MB 46.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 13.8/46.5 MB 46.7 MB/s eta 0:00:01
# ...
